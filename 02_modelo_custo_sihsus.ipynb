# %% [markdown]
# # Notebook 02 — Treinamento do Modelo de Custo SIHSUS

# %% [markdown]
# Este notebook executa o pipeline de treinamento com split temporal e salva os artefatos solicitados.

# %%
import json
from pipeline_modelo_sihsus import treinar_e_salvar

resultado = treinar_e_salvar()
print(json.dumps(resultado, ensure_ascii=False, indent=2))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 import json
#       2 from pipeline_modelo_sihsus import treinar_e_salvar
#       3
# ----> 4 resultado = treinar_e_salvar()
#       5 print(json.dumps(resultado, ensure_ascii=False, indent=2))
#
# File c:\Mackenzie\IA\test_datasus\test-datasus\pipeline_modelo_sihsus.py:226, in treinar_e_salvar()
#     224 cat_cols = [c for c in x_treino.columns if c not in num_cols]
#     225 pipeline = construir_modelo(num_cols=num_cols, cat_cols=cat_cols)
# --> 226 pipeline = ajustar_pipeline(pipeline, x_treino, y_treino)
#     227 metrics, y_pred = avaliar_modelo(pipeline, x_teste, y_teste)
#     229 joblib.dump(pipeline, ARTIFACTS_DIR / "model.pkl")
#
# File c:\Mackenzie\IA\test_datasus\test-datasus\pipeline_modelo_sihsus.py:136, in ajustar_pipeline(modelo, x_treino, y_treino)
# ...

# %%
import json
from pathlib import Path
import pandas as pd

artifacts = Path('artifacts')
payload = json.loads((artifacts / 'metrics.json').read_text(encoding='utf-8'))
pd.DataFrame([payload['metricas']])

# %%
from pathlib import Path

for fig in ['outputs/residuos_modelo.png', 'outputs/predito_vs_real.png']:
    caminho = Path(fig)
    print(fig, 'OK' if caminho.exists() else 'NÃO ENCONTRADO')
